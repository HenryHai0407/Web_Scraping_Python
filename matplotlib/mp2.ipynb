# %%
# !pip install seaborn
import seaborn as sns
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Create a scatter plot
plot = sns.scatterplot(x='total_bill', y='tip', hue='sex', data=df)
plot.set_title('The correlation between Total Bill and Tip')
plot.set_xlabel('Total Bill')
plot.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
grouped_data = df.groupby('sex', as_index=False)['total_bill'].sum()
sns.barplot(x='sex', y='total_bill', data=grouped_data)
# Out:
# C:\Users\ThuBy\AppData\Local\Temp\ipykernel_5516\3454532441.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = df.groupby('sex', as_index=False)['total_bill'].sum()
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
grouped_data1= df.groupby('smoker',as_index=False)['total_bill'].sum()
sns.barplot(x='smoker',y='total_bill',data=grouped_data1)
# Out:
# C:\Users\ThuBy\AppData\Local\Temp\ipykernel_5516\4286367453.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data1= df.groupby('smoker',as_index=False)['total_bill'].sum()
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
# Heatmap chart
import numpy as np
sales_data = np.array([
    [200, 250, 300, 350, 400, 450],
    [180, 220, 290, 340, 390, 460],
    [150, 200, 240, 300, 350, 400]
 ])

# %%
# Draw heatmap
sns.heatmap(sales_data, annot=True, cmap="YlGnBu", xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'], yticklabels=['Product A', 'Product B', 'Product C'])
# Out:
# <Axes: >
